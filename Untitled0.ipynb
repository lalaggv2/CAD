# %% [markdown]
# <a href="https://colab.research.google.com/github/lalaggv2/CAD/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fo = open("/content/letracumpleanos.txt", "r")

print("Nombre del Archivo> ", fo.name)
print("Modo en que se abrio el archivo: ", fo.mode)
fo.close()
# Out:
# Nombre del Archivo>  /content/letracumpleanos.txt
# Modo en que se abrio el archivo:  r

# %%
fo.close
print("Cerrado", fo.closed)
# Out:
# Cerrado True

# %% [markdown]
# simpre hay que cerrar los archivos al terminar de usarlos
